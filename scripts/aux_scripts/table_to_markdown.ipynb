# %%
import pandas as pd
from IPython.display import Markdown, display
import sys
from pathlib import Path
current_dir = Path.cwd()

project_root = current_dir.parent.parent
table_path= project_root / 'docs/raw_input_data_table.xlsx'
table_tab_name= 'table'

gdf = pd.read_excel(table_path,sheet_name=table_tab_name)  # Or from other sources
gdf=gdf.drop(columns='Link for download')
markdown_table = gdf.to_markdown(index=False)
display(Markdown(markdown_table))
# Out:
# | Dataset Name                   | Source                                                                                                             | Format             | Coverage                                | Link/Source                                                                                                                                                                                                                                                   | Download and pre-processing needs                                                                                                                                                                                                                                             |
# ...
