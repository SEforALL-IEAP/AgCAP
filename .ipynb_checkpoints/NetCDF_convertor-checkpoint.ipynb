# %%
import xarray as xr
import rioxarray
import numpy as np

print(np.__version__)
print(xr.__version__)
print(rioxarray.__version__)
# Out:
# 1.23.5
# 2023.6.0
# 0.13.4

# %%
# Step 1: Load NetCDF file
file_path = r'C:\Users\alexl\Downloads\climatology-spei12-annual-mean_cmip6-x0.25_access-cm2-r1i1p1f1-ssp126_climatology_mean_2020-2039.nc'
nc = xr.open_dataset(file_path)

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 1, lat: 721, lon: 1440, bnds: 2)
# Coordinates:
#   * time                            (time) datetime64[ns] 2020-07-01
#   * lat                             (lat) float32 -90.0 -89.75 ... 89.75 90.0
#   * lon                             (lon) float32 -180.0 -179.8 ... 179.5 179.8
#   * bnds                            (bnds) int32 0 1
# Data variables:
#     climatology-spei12-annual-mean  (time, lat, lon) float32 ...
#     lon_bnds                        (lon, bnds) float64 ...
#     lat_bnds                        (lat, bnds) float64 ...
# Attributes: (12/13)
#     wb_truncation_label:   2
#     wb_grid_label:         x0.25
#     wb_period_label:       2020-2039
#     wb_percentile_label:   mean
#     wb_type_label:         climatology
#     wb_model_label:        access-cm2
#     ...                    ...
#     wb_scenario_label:     ssp126
#     wb_statistic_label:    mean
#     wb_aggregation_label:  annual
#     wb_variable_label:     spei12
#     wb_product_label:      climatology
#     wb_collection_label:   cmip6-x0.25

# %%
# Step 2: Display available dimensions and variables
print("Dimensions:\n", nc.dims)
print("\nVariables:\n", nc.data_vars)
# Out:
# Dimensions:
#  Frozen({'time': 1, 'lat': 721, 'lon': 1440, 'bnds': 2})
#
# Variables:
#  Data variables:
#     climatology-spei12-annual-mean  (time, lat, lon) float32 ...
#     lon_bnds                        (lon, bnds) float64 ...
#     lat_bnds                        (lat, bnds) float64 ...

# %%
# Step 3: Select a variable and specific dimensions
variable_name = 'climatology-spei12-annual-mean'  # Replace with your variable name
selected_var = nc[variable_name]

# %%
# Optional: If the variable has multiple dimensions (e.g., time), select a specific slice
if 'time' in selected_var.dims:
    selected_var = selected_var.isel(time=0)  # Select the first time slice

# %%
# Ensure the DataArray has the necessary spatial metadata
if not selected_var.rio.crs:
    selected_var = selected_var.rio.write_crs("EPSG:4326", inplace=True)

# %%
# Export to raster
selected_var.rio.to_raster('spei12.tif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Export to raster
# ----> 2 selected_var.rio.to_raster('spei12.tif')
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\rioxarray\raster_array.py:1146, in RasterArray.to_raster(self, raster_path, driver, dtype, tags, windowed, recalc_transform, lock, compute, **profile_kwargs)
#    1127 out_profile = {
#    1128     key: value
#    1129     for key, value in out_profile.items()
#    (...)
#    1140     )
#    1141 }
#    1142 rio_nodata = (
#    1143     self.encoded_nodata if self.encoded_nodata is not None else self.nodata
#    1144 )
# -> 1146 return RasterioWriter(raster_path=raster_path).to_raster(
#    1147     xarray_dataarray=self._obj,
#    1148     tags=tags,
#    1149     driver=driver,
#    1150     height=int(self.height),
#    1151     width=int(self.width),
#    1152     count=int(self.count),
#    1153     dtype=dtype,
#    1154     crs=self.crs,
#    1155     transform=self.transform(recalc=recalc_transform),
#    1156     gcps=self.get_gcps(),
#    1157     nodata=rio_nodata,
#    1158     windowed=windowed,
#    1159     lock=lock,
#    1160     compute=compute,
#    1161     **out_profile,
#    1162 )
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\rioxarray\raster_writer.py:288, in RasterioWriter.to_raster(self, xarray_dataarray, tags, windowed, lock, compute, **kwargs)
#     286 else:
#     287     out_data = xarray_dataarray
# --> 288 data = encode_cf_variable(out_data).values.astype(numpy_dtype)
#     289 if data.ndim == 2:
#     290     rds.write(data, 1, window=window)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\conventions.py:190, in encode_cf_variable(var, needs_copy, name)
#     178 ensure_not_multiindex(var, name=name)
#     180 for coder in [
#     181     times.CFDatetimeCoder(),
#     182     times.CFTimedeltaCoder(),
#    (...)
#     188     variables.BooleanCoder(),
#     189 ]:
# --> 190     var = coder.encode(var, name=name)
#     192 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     193 var = ensure_dtype_not_object(var, name=name)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\coding\times.py:704, in CFDatetimeCoder.encode(self, variable, name)
#     701 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     702     if np.issubdtype(
#     703         variable.data.dtype, np.datetime64
# --> 704     ) or contains_cftime_datetimes(variable):
#     705         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     707         (data, units, calendar) = encode_cf_datetime(
#     708             data, encoding.pop("units", None), encoding.pop("calendar", None)
#     709         )
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\core\common.py:2013, in contains_cftime_datetimes(var)
#    2011 def contains_cftime_datetimes(var: T_Variable) -> bool:
#    2012     """Check if an xarray.Variable contains cftime.datetime objects"""
# -> 2013     return _contains_cftime_datetimes(var._data)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'DataArray' object has no attribute '_data'

# %%
# Step 4: Convert to a raster and save as GeoTIFF
selected_var = selected_var.rio.write_crs("EPSG:4326")  # Set CRS, adjust if needed
output_path = 'C:/Users/alexl/Dropbox/GitHub/AgCAP/GIS_data/spei12/spei12.tif'
selected_var.rio.to_raster(output_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       2 selected_var = selected_var.rio.write_crs("EPSG:4326")  # Set CRS, adjust if needed
#       3 output_path = 'C:/Users/alexl/Dropbox/GitHub/AgCAP/GIS_data/spei12/spei12.tif'
# ----> 4 selected_var.rio.to_raster(output_path)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\rioxarray\raster_array.py:1146, in RasterArray.to_raster(self, raster_path, driver, dtype, tags, windowed, recalc_transform, lock, compute, **profile_kwargs)
#    1127 out_profile = {
#    1128     key: value
#    1129     for key, value in out_profile.items()
#    (...)
#    1140     )
#    1141 }
#    1142 rio_nodata = (
#    1143     self.encoded_nodata if self.encoded_nodata is not None else self.nodata
#    1144 )
# -> 1146 return RasterioWriter(raster_path=raster_path).to_raster(
#    1147     xarray_dataarray=self._obj,
#    1148     tags=tags,
#    1149     driver=driver,
#    1150     height=int(self.height),
#    1151     width=int(self.width),
#    1152     count=int(self.count),
#    1153     dtype=dtype,
#    1154     crs=self.crs,
#    1155     transform=self.transform(recalc=recalc_transform),
#    1156     gcps=self.get_gcps(),
#    1157     nodata=rio_nodata,
#    1158     windowed=windowed,
#    1159     lock=lock,
#    1160     compute=compute,
#    1161     **out_profile,
#    1162 )
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\rioxarray\raster_writer.py:288, in RasterioWriter.to_raster(self, xarray_dataarray, tags, windowed, lock, compute, **kwargs)
#     286 else:
#     287     out_data = xarray_dataarray
# --> 288 data = encode_cf_variable(out_data).values.astype(numpy_dtype)
#     289 if data.ndim == 2:
#     290     rds.write(data, 1, window=window)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\conventions.py:190, in encode_cf_variable(var, needs_copy, name)
#     178 ensure_not_multiindex(var, name=name)
#     180 for coder in [
#     181     times.CFDatetimeCoder(),
#     182     times.CFTimedeltaCoder(),
#    (...)
#     188     variables.BooleanCoder(),
#     189 ]:
# --> 190     var = coder.encode(var, name=name)
#     192 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     193 var = ensure_dtype_not_object(var, name=name)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\coding\times.py:704, in CFDatetimeCoder.encode(self, variable, name)
#     701 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     702     if np.issubdtype(
#     703         variable.data.dtype, np.datetime64
# --> 704     ) or contains_cftime_datetimes(variable):
#     705         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     707         (data, units, calendar) = encode_cf_datetime(
#     708             data, encoding.pop("units", None), encoding.pop("calendar", None)
#     709         )
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\core\common.py:2013, in contains_cftime_datetimes(var)
#    2011 def contains_cftime_datetimes(var: T_Variable) -> bool:
#    2012     """Check if an xarray.Variable contains cftime.datetime objects"""
# -> 2013     return _contains_cftime_datetimes(var._data)
#
# File ~\anaconda3\envs\agcap_netcdf\lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'DataArray' object has no attribute '_data'

# %%
print(f"Raster saved successfully at {output_path}")
# Out:
# Raster saved successfully at C:/Users/alexl/Dropbox/GitHub/AgCAP/GIS_data/spei12/spei12.tif
